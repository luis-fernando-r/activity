# %%
a_clase_1 = [
           [(450,1150),(2050,2200)], #1
           [(1000,1250),(2150,2410)], 
           [(1050,1150),(2410,2510)], #esta rarisimo
           [(990,1290),(2100,2400)],
           [(1080,1400),(1950,2220)], #5
           [(1240,1500),(2100,2350)],
           [(1100,1300),(2370,2510)],
           [(900,1100),(2090,2470)],
           [(800,1240),(2150,2730)],
           [(910,1250),(1970,2300)], #10
           [(500,1070),(2100,2300)],
           [(590,1120),(2100,2300)],
           [(870,970),(1990,2200)],
           [(850,1200),(2160,2400)],
           [(1170,1460),(2030,2270)],#15
           [(760,1030),(1990,2420)],
           [(870,1450),(1900,2190)],
           [(850,1050),(1900,2250)],
           [(560,1270),(2000,2590)],
           [(240,1150),(2040,2720)],#20
           ]
b_clase_1 = [
           [(910,1170),(1700,1950)], #1
           [(930,1270),(1890,2270)], 
           [(1290,1530),(2300,2660)], #esta rarisimo
           [(1050,1440),(1800,2220)],
           [(850,970),(2050,2200)],#5
           [(1090,1150),(2040,2130)],
           [(1240,1350),(2310,2450)],
           [(800,1270),(1800,2600)],
           [(900,1720),(2100,2850)],
           [(950,1400),(1900,2530)],#10
           [(1040,1470),(2100,2500)],
           [(1100,1370),(2000,2370)],
           [(1280,1450),(2050,2490)],
           [(890,1150),(2300,2630)],
           [(900,1100),(2170,2400)],#15
           [(880,1350),(1950,2460)],
           [(1040,1450),(1830,2350)],
           [(950,1450),(1800,2430)],
           [(1100,1450),(1930,2200)],
           [(1150,1460),(2000,2400)],#20
           ]

# %%
a_clase_2 = [
           [(470,1900)],#1
           [(630,1750)],
           [(400,1800)],
           [(600,1850)],
           [(570,1850)],#5
           [(730,1950)],
           [(600,1700)],
           [(620,1600)],
           [(560,1630)],
           [(700,1780)],#10
           [(750,1800)],
           [(850,1950)],
           [(700,1830)],
           [(640,1830)],
           [(700,1900)],#15
           [(650,1580)],
           [(380,1780)],
           [(550,1850)],
           [(700,1800)],
           [(600,1700)],#20
          ]
b_clase_2 = [
           [(550,1660)],#1
           [(600,1680)],
           [(370,1700)],
           [(500,1650)],
           [(650,1650)],
           [(550,1680)],#5
           [(680,1550)],
           [(570,1540)],
           [(700,1650)],
           [(560,1600)],
           [(750,1670)],#10
           [(730,1770)],
           [(1040,1990)],
           [(630,1600)],
           [(600,1550)],
           [(580,1670)],#15
           [(700,1630)],
           [(630,1730)],
           [(700,1830)],
           [(640,1700)],
           [(530,1700)],#20
          ]

# %%
a_clase_3 = [
           [(440,1700)],#1
           [(550,1580)],
           [(820,1800)],
           [(700,1900)],
           [(600,1650)],#5
           [(540,1600)],
           [(360,1730)],
           [(600,1790)],
           [(880,1800)],
           [(550,1930)],#10
           [(900,1930)],
           [(600,1930)],
           [(640,1900)],
           [(650,1830)],
           [(1000,1990)],#15
           [(640,1700)],
           [(630,1750)],
           [(630,1950)],
           [(740,1970)],
           [(530,1670)],#20
          ]
b_clase_3 = [
           [(650,1700)],#1
           [(700,1650)],
           [(780,1750)],
           [(770,1700)],
           [(600,1600)],#5
           [(720,1770)],
           [(400,1500)],
           [(550,1550)],
           [(820,1620)],
           [(550,1950)],#10
           [(700,1650)],
           [(600,1830)],
           [(530,1680)],
           [(620,1550)],
           [(500,1460)],#15
           [(700,1800)],
           [(500,1550)],
           [(620,1800)],
           [(740,1730)],
           [(500,1700)],#20
          ]

# %%
a_clase_4 = [
           [(550,800),(1020,1200),(1400,1530)],#1
           [(530,800),(1000,1100),(1400,1550)],
           [(500,680),(750,1100),(1420,1790)],
           [(690,850),(1240,1400),(1620,1840)],
           [(300,670),(880,1240),(1550,1780)],#5
           [(570,700),(1050,1250),(1550,1990)],
           [(550,850),(1200,1450),(1700,1800)],
           [(650,970),(1140,1340),(1600,1900)],
           [(300,500),(700,900),(1450,1750)],
           [(550,800),(1050,1350),(1570,1750)],#10
           [(300,500),(900,1150),(1550,1850)],
           [(550,800),(1150,1250),(1600,1900)],
           [(600,890),(1150,1380),(1600,1900)],
           [(400,600),(1000,1250),(1400,1700)],
           [(550,730),(1100,1350),(1450,1850))],#15
           [(570,730),(1040,1280),(1700,1900)],
           [(620,900),(1150,1430),(1600,1780)],
           [(650,830),(1050,1230),(1540,1700)],
           [(540,750),(1050,1200),(1700,1880)],
           [(720,850),(1230,1400),(1650,1850)],#20
          ]
b_clase_4 = [
           [(630,800),(1030,1250),(1450,1580)],#1
           [(350,600),(1100,1550)],
           [(650,800),(1050,1180),(1480,1880)],
           [(300,500),(1180,1450),(1600,1740)],
           [(500,700),(850,1150),(1480,1700)],#5
           [(630,770),(1100,1300),(1550,1750)],
           [(450,550),(930,1050),(1300,1450)],
           [(640,800),(1050,1180),(1550,1780)],
           [(600,800),(1200,1320),(1650,1730)],
           [(640,750),(1100,1450),(1550,1750)],#10
           [(600,750),(1200,1350),(1550,1750)],
           [(650,750),(1170,1300),(1600,1650)],
           [(650,740),(1180,1260),(1680,1750)],
           [(700,790),(1080,1340),(1600,1850)],
           [(720,790),(1250,1400),(1800,1930))],#15
           [(740,850),(1100,1240),(1820,1950)],
           [(750,980),(1350,1510),(1700,1800)],
           [(700,880),(1100,1250),(1630,1750)],
           [(490,750),(980,1120),(1650,1800)],
           [(700,880),(1200,1270),(1600,1800)],#20
          ]
